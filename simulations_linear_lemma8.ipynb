# %% [markdown]
# # Optimal adjustment simulations
#
# Code by Jacqueline Maasch | April 2025

# %% [markdown]
# ## Preamble

# %%
# General importations.
import pandas as pd
import numpy as np
import sys
import time
import matplotlib.pyplot as plt
import platform
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from os import listdir
from os.path import isfile, join
import itertools
#plt.rcParams["figure.figsize"] = (2,2)

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import networkx as nx
from econml.dml import DML, LinearDML, SparseLinearDML, CausalForestDML
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import (Lasso, LassoCV, LogisticRegression,
                                  LogisticRegressionCV,LinearRegression,
                                  MultiTaskElasticNet,MultiTaskElasticNetCV)
from sklearn.ensemble import (RandomForestRegressor,RandomForestClassifier,
                              GradientBoostingRegressor,GradientBoostingClassifier)
from dowhy import CausalModel
import dowhy.datasets

# Custom scripts.
from effect_estimation import Estimator
from data_generation import DataGenerator
from utils import Utils

# View versioning.
print("python version     :", platform.python_version())
print("numpy version      :", np.__version__)
print("pandas version     :", pd.__version__)
print("matplotlib version :", matplotlib.__version__)
print("seaborn version    :", sns.__version__)
# Out:
# python version     : 3.10.13
# numpy version      : 1.26.3
# pandas version     : 2.1.4
# matplotlib version : 3.8.0
# seaborn version    : 0.12.2
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %% [markdown]
# ## Generate data

# %%
dg = DataGenerator()
u = Utils()

# %%
# Test single sample.
n = 1000
coefficient_range = (1.1, 1.25)
xy_coeff = 1.0
x_causes_y = True

df, g = dg.get_data_lemma_8(n = n, 
                            x_causes_y = x_causes_y,
                            xy_coeff = xy_coeff,
                            coefficient_range = coefficient_range)

# %%
display(df.head())
# Out:
#           A         Y        B1        G1        G2
# 0 -1.325519 -5.395680 -2.491866 -3.314660 -0.673985
# 1  0.308221  0.608789 -0.030237 -0.771326  0.433098
# 2 -0.146166 -4.029977 -0.240823 -1.720210 -0.864585
# 3  0.740149  6.525472  2.575989  4.087716  1.137297
# 4 -1.066661 -4.010388 -2.238819 -1.511246  0.079828

# %%
_ = df.hist(figsize = (6,6))
plt.show()

# %%
# Scale data.
scaler = StandardScaler()
scaled_values = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_values, columns = df.columns)
_ = scaled_df.hist(figsize = (6,6))
plt.show()

# %%
u.plot_from_graph(g, figsize = (2,2), dpi = 100, node_size = 500)

# %%
# Get replicate samples.
reps = 100
sizes = [1000, 5000, 10000, 50000, 100000, 500000, 1000000]
coefficient_range = (1.1, 1.25)
xy_coeff = 1.25
x_causes_y = True
scale = False

df_dict = dict()
for size in sizes:
    dfs = []
    for rep in range(reps):
        df, _ = dg.get_data_lemma_8(n = size, 
                                    x_causes_y = x_causes_y,
                                    xy_coeff = xy_coeff,
                                    coefficient_range = coefficient_range,
                                    scale = scale)
        dfs.append(df)
    df_dict[size] = dfs

# %%
len(df_dict.get(5000))
# Out:
# 100

# %% [markdown]
# ## Estimate WCDE

# %%
e = Estimator()
exposure = "A"
outcome = "Y"
covars = ["B1", "G1", "G2"]
powerset = u.get_powerset(covars)
powerset = [list(x) for x in powerset]
colors = ["#FDBC42", "#41B0E4", "#C6DC67", "#F69289", 
          "#7977B8", "#2D2F92", "#F26035", "#3FBC9D"]

# %%
# Single estimate.
for adj_set in powerset:
    wcde = e.get_wcde(df = df, 
                      exposure = exposure, 
                      outcome = outcome, 
                      parents = adj_set, 
                      linear_regression = True,
                      verbose = False)
    print(adj_set, ":", wcde)
# Out:
# [] : 5.051602587356178
# ['B1'] : 1.2092621336476326
# ['G1'] : 1.1960556877866417
# ['G2'] : 2.9180983012556307
# ['B1', 'G1'] : 1.235306261088464
# ['B1', 'G2'] : 1.2513110222758261
# ['G1', 'G2'] : 1.2495932973626185
# ['B1', 'G1', 'G2'] : 1.2489602759025675

# %% [markdown]
# ### Scale sample size

# %%
results = dict()
for adj_set in powerset:
    means = []
    variances = []
    for size,dfs in df_dict.items():
        estimates = []
        for df in dfs:
            wcde = e.get_wcde(df = df, 
                              exposure = exposure, 
                              outcome = outcome, 
                              parents = adj_set, 
                              linear_regression = True,
                              verbose = False)
            estimates.append(wcde)
        means.append(np.mean(estimates))
        variances.append(np.var(estimates))
    results[str(adj_set)] = [means,variances]

# %%
for key,value in results.items():
    print(key, ":", value)
# Out:
# [] : [[4.920901484655326, 4.935780781258291, 4.940076930200102, 4.962906190065193, 4.947627529678599, 4.936051536506045, 4.928733113486499], [0.0380696483522956, 0.03580971443063091, 0.033615291557326794, 0.028429995160119764, 0.027643715392787437, 0.028020161362457885, 0.031247526338888085]]
# ['B1'] : [[1.0934775642031653, 1.1186101429526278, 1.121500247712283, 1.1079167421543925, 1.1111725863970376, 1.1165551834800251, 1.1078410985766438], [0.009879220287908877, 0.00415943915191223, 0.005012213893260221, 0.003566800017621173, 0.003460112069272662, 0.003233764993692422, 0.0024362040945279054]]
# ['G1'] : [[1.17435734952769, 1.1796026400862045, 1.1823893744336031, 1.178086186832697, 1.179525743931887, 1.1822200141015744, 1.177827973363114], [0.002784017655523621, 0.0007077190090479492, 0.0006981328777031115, 0.000462710232117444, 0.0004166178441456331, 0.0003796626632137751, 0.0002932753501646525]]
# ['G2'] : [[2.851308854365744, 2.8737471393339376, 2.873307185154414, 2.886067887022741, 2.8866458933031782, 2.8801233721058246, 2.871873772428321], [0.013404792309996192, 0.013073556576879608, 0.013239013757243416, 0.011088048982547479, 0.010059214610210275, 0.009897080803234192, 0.013375718999077395]]
# ['B1', 'G1'] : [[1.2003455215484613, 1.2037830331731174, 1.2075636819715767, 1.202434619668142, 1.2036781781474888, 1.2050356869190377, 1.20257171634143], [0.003049381191494641, 0.000662009698393441, 0.0007995986537447612, 0.0004533651263653548, 0.00044948293583341273, 0.0003659384328681374, 0.0002832840162013274]]
# ['B1', 'G2'] : [[1.2340069967260345, 1.2534526678030224, 1.250662954979314, 1.2508366145284053, 1.250770535574204, 1.250152397866335, 1.2497753508506744], [0.003622209181370105, 0.0011264729613605859, 0.000533933725756478, 0.00012008235651050709, 5.829046643116063e-05, 1.206001124103082e-05, 4.560217485907741e-06]]
# ['G1', 'G2'] : [[1.243700588823681, 1.2485732326793006, 1.250298282342096, 1.249982835445908, 1.2504208238953274, 1.2500446105657912, 1.2499332902101121], [0.0015788651259712799, 0.00040616994217959656, 0.00016776842911729213, 3.496927874681189e-05, 2.3001898678375195e-05, 3.6319852715408413e-06, 1.624508234097524e-06]]
# ['B1', 'G1', 'G2'] : [[1.245108171327688, 1.2499697515282207, 1.2506412466467243, 1.250314158036318, 1.2506557287467757, 1.250075728073426, 1.2499280602886567], [0.0016332767056254373, 0.00041869249895149315, 0.00020815593970246036, 4.863640455063484e-05, 2.9482133576579648e-05, 4.623347629627712e-06, 2.2609152443809917e-06]]

# %% [markdown]
# ## Plot results

# %%
# Compare G2,B1 and G2,B1,G1.
plt.plot(sizes, 
         results.get("['B1', 'G1', 'G2']")[1], 
         label = "['B1', 'G1', 'G2']", 
         color = colors[0])
plt.plot(sizes, 
         results.get("['B1', 'G2']")[1],
         label = "['B1', 'G2']", 
         color = colors[1])
plt.legend(loc = 'upper right')
plt.xlabel('\nSample size')
plt.ylabel('Estimate variance\n')
plt.xlim(sizes[0],sizes[-1])
plt.xscale('symlog')
plt.show()

# %%
# Compare G2,B1 and G2,B1,G1.
plt.plot(sizes, 
         results.get("['B1', 'G1', 'G2']")[0], 
         label = "['B1', 'G1', 'G2']", 
         color = colors[0])
plt.plot(sizes, 
         results.get("['B1', 'G2']")[0],
         label = "['B1', 'G2']", 
         color = colors[1])
plt.axhline(y = xy_coeff, color = '#EE2967', linestyle = '--', linewidth = 0.75)
plt.legend(loc = 'upper right')
plt.xlabel('\nSample size')
plt.ylabel('Estimate mean\n')
plt.xlim(sizes[0],sizes[-1])
plt.xscale('symlog')
plt.show()

# %%
i = 0
for key,value in results.items():
    plt.plot(sizes, value[1], label = key, color = colors[i])
    i += 1
plt.legend(loc = 'upper right')
plt.xlabel('\nSample size')
plt.ylabel('Estimate variance\n')
plt.xlim(sizes[0],sizes[-1])
plt.xscale('symlog')
plt.show()

# %%
i = 0
for key,value in results.items():
    plt.plot(sizes, value[0], label = key, color = colors[i], linewidth = 2)
    i += 1
plt.legend(loc = 'upper right')
plt.xlabel('\nSample size')
plt.ylabel('Estimate mean\n')
plt.axhline(y = xy_coeff, color = '#EE2967', linestyle = '--', linewidth = 0.75)
plt.xlim(sizes[0],sizes[-1])
plt.xscale('symlog')
plt.show()
